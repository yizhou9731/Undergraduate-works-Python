# %%
# project: p10
# submitter-netid: yzhou344
# partner-netid: none

# %%
import pandas as pd

# %%
import requests

# %%
import numpy as np

# %%
from pandas import DataFrame, Series

# %%
'''r = requests.get(url)
r.raise_for_status()
data = r.text
f = open("countries.json", "w", encoding="utf-8")
f.write(data)
f.close()
f = open("countries.json", encoding="utf-8")
data = f.read()
f.close()
'''
# Out:
# 'r = requests.get(url)\nr.raise_for_status()\ndata = r.text\nf = open("countries.json", "w", encoding="utf-8")\nf.write(data)\nf.close()\nf = open("countries.json", encoding="utf-8")\ndata = f.read()\nf.close()\n'

# %%
url= "https://tyler.caraza-harter.com/cs301/spring19/data/countries.json"
df = pd.read_json(url)
big_df=df
big_df
# Out:
#         area  birth-rate  coastline      continent               country  \
# 0     756950       15.23       0.85  South America                 Chile
# 1        665       17.80      24.21           Asia               Bahrain
# 2      22966       28.84       1.68  North America                Belize
# 3     582650       39.72       0.09         Africa                 Kenya
# 4      11854       33.05       3.12      Australia      Marshall Islands
# 5     111370       44.77       0.52         Africa               Liberia
# 6     504782       10.06       0.98         Europe                 Spain
# 7      65610       15.51       2.04           Asia             Sri Lanka
# 8     212460       36.24       0.98           Asia                  Oman
# 9        316       10.22      62.28         Europe                 Malta
# 10    185180       27.76       0.10           Asia                 Syria
# 11   1759540       26.49       0.10         Africa                 Libya
# ...

# %%
#q1
df["area"].sum()
# Out:
# 127493303

# %%
from requests import get

# %%
url="https://tyler.caraza-harter.com/cs301/spring19/data/capitals/manifest.txt"
r = requests.get(url)
r.raise_for_status()
data = r.text
f = open("manifest.txt", "w", encoding="utf-8")
f.write(data)
f.close()
manifest=data.split("\n")[0:-1]
manifest
# Out:
# ['Brazil_Peru.json',
#  'ElSalvador_SaintHelena.json',
#  'Ghana_Belize.json',
#  'Palau_Nigeria.json',
#  'Portugal_Somalia.json',
#  'Seychelles_Cuba.json',
#  'Slovenia_Estonia.json',
#  'Tanzania_Swaziland.json',
#  'Vanuatu_Tajikistan.json']

# %%
#q2
manifest[0]
# Out:
# 'Brazil_Peru.json'

# %%
import os

# %%
def get_json(url):
    r = requests.get(url)
    r.raise_for_status()
    data = r.json()
    tdata=r.text
    path=url.split("/")[-1]
    
    #print("11")
    if os.path.exists(path)==True:
        #print("11")
        return data
        
    else:
        f = open("Ghana_Belize.json", "w", encoding="utf-8")
        #data=json.dump(data)
        f.write(tdata)
        f.close()
        #print("yeeeeeh")
        return data

# %%
get_json("https://tyler.caraza-harter.com/cs301/spring19/data/capitals/Palau_Nigeria.json")
# Out:
# [{'capital': 'Melekeok',
#   'country': 'Palau',
#   'latitude': 7.4833333333333325,
#   'longitude': 134.633333},
#  {'capital': 'Baghdad',
#   'country': 'Iraq',
#   'latitude': 33.333333333333336,
#   'longitude': 44.4},
#  {'capital': 'Majuro',
#   'country': 'Marshall Islands',
#   'latitude': 7.1,
#   'longitude': 171.383333},
#  {'capital': 'Muscat',
#   'country': 'Oman',
#   'latitude': 23.61666666666667,
#   'longitude': 58.583332999999996},
#  {'capital': 'Kabul',
#   'country': 'Afghanistan',
#   'latitude': 34.516666666666666,
#   'longitude': 69.18333299999999},
#  {'capital': 'Paramaribo',
#   'country': 'Suriname',
#   'latitude': 5.833333333333332,
#   'longitude': -55.166667000000004},
#  {'capital': 'Reykjavik',
#   'country': 'Iceland',
#   'latitude': 64.15,
#   'longitude': -21.95},
#  {'capital': 'Madrid',
#   'country': 'Spain',
#   'latitude': 40.4,
#   'longitude': -3.683333},
#  {'capital': 'Athens',
#   'country': 'Greece',
# ...

# %%
#q3
base="https://tyler.caraza-harter.com/cs301/spring19/data/capitals/"
capital_rows=[]
for json in manifest:
    url=base+json
    capital_rows+=get_json(url)
capital_rows
# Out:
# [{'capital': 'Brasilia',
#   'country': 'Brazil',
#   'latitude': -15.783333333333333,
#   'longitude': -47.916667},
#  {'capital': 'Nouakchott',
#   'country': 'Mauritania',
#   'latitude': 18.066666666666666,
#   'longitude': -15.966667000000001},
#  {'capital': 'Bern',
#   'country': 'Switzerland',
#   'latitude': 46.91666666666666,
#   'longitude': 7.466667},
#  {'capital': 'Zagreb',
#   'country': 'Croatia',
#   'latitude': 45.8,
#   'longitude': 16.0},
#  {'capital': 'Cairo',
#   'country': 'Egypt',
#   'latitude': 30.05,
#   'longitude': 31.25},
#  {'capital': 'Sanaa',
#   'country': 'Yemen',
#   'latitude': 15.35,
#   'longitude': 44.2},
#  {'capital': 'Helsinki',
#   'country': 'Finland',
#   'latitude': 60.16666666666666,
#   'longitude': 24.933332999999998},
#  {'capital': 'Addis Ababa',
#   'country': 'Ethiopia',
#   'latitude': 9.033333333333333,
#   'longitude': 38.7},
#  {'capital': 'Prague',
#   'country': 'Czech Republic',
#   'latitude': 50.08333333333334,
# ...

# %%
capitals = DataFrame(capital_rows)

# %%
#q4
df_row=capitals.loc[capitals["country"]=="Bermuda"]
answer=df_row["capital"]
Series.item(answer)
# Out:
# 'Hamilton'

# %%
#q5 
df_row=capitals.loc[capitals["capital"]=="Maputo"]
answer=df_row["country"]
Series.item(answer)
# Out:
# 'Mozambique'

# %%
capitals.loc[0:3]
# Out:
#       capital      country   latitude  longitude
# 0    Brasilia       Brazil -15.783333 -47.916667
# 1  Nouakchott   Mauritania  18.066667 -15.966667
# 2        Bern  Switzerland  46.916667   7.466667
# 3      Zagreb      Croatia  45.800000  16.000000

# %%
#q6
li_cap=[]
r_latitude=capitals.sort_values(by=["latitude"])
answer=r_latitude.iloc[0:5]["country"]
for cap in answer:
    
    li_cap.append(cap)
li_cap
# Out:
# ['New Zealand', 'Australia', 'Uruguay', 'Argentina', 'Chile']

# %%
#q7
nli_cap=[]
r_latitude=capitals.sort_values(by=["latitude"],ascending=False)
answer=r_latitude.iloc[0:3]["country"]
for cap in answer:
    
    nli_cap.append(cap)
nli_cap
# Out:
# ['Iceland', 'Finland', 'Norway']

# %%
#q8
summary=big_df[["birth-rate","death-rate"]]
summary.describe()
# Out:
#        birth-rate  death-rate
# count  175.000000  175.000000
# mean    22.536114    9.654971
# std     11.287090    5.187216
# min      8.250000    2.410000
# 25%     12.635000    6.075000
# 50%     20.340000    8.230000
# 75%     30.200000   11.965000
# max     50.730000   29.740000

# %%
#q9
'''
summary=big_df[["literacy"]] 
a=summary.loc[1]
a=Series.item(a)
a=a.replace(",",".")
a
'''
summary=big_df

summary["literacy"] = summary["literacy"].astype(str).str.replace(',','.').astype(float)
summary["phones"] = summary["phones"].astype(str).str.replace(',','.').astype(float)

table=summary[["literacy","phones"]]
table.describe()
# Out:
#          literacy       phones
# count  175.000000   175.000000
# mean    82.182286   214.621143
# std     20.086897   218.613971
# min     17.600000     1.300000
# 25%     69.950000    31.300000
# 50%     92.000000   140.100000
# 75%     98.000000   329.700000
# max    100.000000  1035.600000

# %%
def find_ll(continent):
    rows_1=big_df.loc[big_df["coastline"]==0]
    rows_2=rows_1.loc[rows_1["continent"]==continent]
    ranked=rows_2.sort_values(by=["area"],ascending=False)
    return ranked.iloc[0]["country"]

# %%
#q10
find_ll("Europe")
# Out:
# 'Belarus'

# %%
#q11
find_ll("Africa")
# Out:
# 'Chad'

# %%
#q12
find_ll("South America")
# Out:
# 'Bolivia'

# %%
#Haversine formula is used to compute distance. 
#Haversine Formula (from R.W. Sinnott, "Virtues of the Haversine", 
#Sky and Telescope, vol. 68, no. 2, 1984, p. 159)
#Source: http://www.movable-type.co.uk/scripts/gis-faq-5.1.html

# %%
#Formula:
'''

dlon = lon2 - lon1
dlat = lat2 - lat1
a = sin^2(dlat/2) + cos(lat1) * cos(lat2) * sin^2(dlon/2)
c = 2 * arcsin(min(1,sqrt(a)))
d = R * c

'''
# Out:
# '\n\ndlon = lon2 - lon1\ndlat = lat2 - lat1\na = sin^2(dlat/2) + cos(lat1) * cos(lat2) * sin^2(dlon/2)\nc = 2 * arcsin(min(1,sqrt(a)))\nd = R * c\n\n'

# %%
import math as m

# %%
def get_distance(lat1,lon1,lat2,lon2):
    lon1=m.radians(lon1)
    lon2=m.radians(lon2)
    lat1=m.radians(lat1)
    lat2=m.radians(lat2)
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (m.sin(dlat/2))**2 + m.cos(lat1) * m.cos(lat2) * (m.sin(dlon/2))**2
    c = 2 * m.asin(min(1,m.sqrt(a)))
    R=3956
    d = R * c
    return d

# %%
#q13
get_distance(43.070231,-89.411893,43.074645,-89.384113)
# Out:
# 1.433899492072933

# %%
def country_distance2(country1,country2):
    r_1=capitals.loc[capitals["country"]==country1]
    r_2=capitals.loc[capitals["country"]==country2]

    lat1=Series.item(r_1["latitude"])
    lon1=Series.item(r_1["longitude"])
    lat2=Series.item(r_2["latitude"])
    lon2=Series.item(r_2["longitude"])
    
    return get_distance(lat1,lon1,lat2,lon2)

# %%
#q14
country_distance2("India","Brazil")
# Out:
# 8840.574141306946

# %%
DataFrame({"country1":{"coun1":0,"coun2":3},
           "country2":{"coun1":3,"coun2":0}})
#dict structure (perhaps named dist) 
#such that dist[country1][country2] is the distance between country1 and country2.
# Out:
#        country1  country2
# coun1         0         3
# coun2         3         0

# %%
def dis_table(inputlist):
    dic={}
    infodic={}
    same=inputlist
    
    
    for country in inputlist:
    
        for country2 in same:
            if country2 == country:
                 infodic[country2]=np.nan
            else:
            
                #str((country_distance2(country,country2))).replace("0.000000","NaN")
                infodic[country2]=country_distance2(country,country2)
            
                
            
        dic[country]=infodic
        infodic={}
    
        
    return dic

# %%
#q15 
inputlist=["Chile","Guyana","Colombia"]  
orig=dis_table(inputlist)
DataFrame(orig)
# Out:
#                 Chile       Guyana     Colombia
# Chile             NaN  2897.553095  2636.644599
# Colombia  2636.644599  1105.066312          NaN
# Guyana    2897.553095          NaN  1105.066312

# %%
#q16
rows=big_df.loc[big_df["continent"] == "South America"]
clist=[]
answer=rows["country"]
for country in answer:
    clist.append(country)
inputlist=clist
orig=dis_table(inputlist)
sa=DataFrame(orig)
sa
# Out:
#                  Chile       Guyana     Colombia     Suriname       Brazil  \
# Argentina   690.784168  2857.520462  2885.355610  2799.886429  1459.139733
# Bolivia    1180.741903  1747.772670  1512.119255  1778.772975  1342.297074
# Brazil     1869.737031  1709.071018  2275.516286  1572.674233          NaN
# Chile              NaN  2897.553095  2636.644599  2895.810776  1869.737031
# Colombia   2636.644599  1105.066312          NaN  1303.405134  2275.516286
# Ecuador    2350.207788  1483.193753   451.004119  1661.699022  2344.584922
# Guyana     2897.553095          NaN  1105.066312   215.336336  1709.071018
# Paraguay    963.635535  2214.288286  2337.615967  2153.855447   908.185709
# Peru       1531.480189  1837.860149  1167.505359  1944.750017  1967.770515
# Suriname   2895.810776   215.336336  1303.405134          NaN  1572.674233
# Uruguay     833.403262  2878.638295  2962.230943  2809.744412  1412.096335
# ...

# %%
#q17
#.mean& .sum: all dataframe. 
#.mean(axis=1): mean for rows
mean_df=sa.astype(float).mean()
mean_df.sort_values().index[0]
# Out:
# 'Bolivia'

# %%
#q18 
mean_df.sort_values().index[-1]
# Out:
# 'Uruguay'

# %%
import copy

# %%
#q19
import numpy
header=sa.columns.values.tolist()
table=DataFrame(index=header,columns=["nearest","distance"])
for country in header:
    table["nearest"][country]=sa[country].astype("float").idxmin()
    table["distance"][country]=sa[country].min()
table.round(6)
# Out:
#              nearest distance
# Chile      Argentina  690.784
# Guyana      Suriname  215.336
# Colombia     Ecuador  451.004
# Suriname      Guyana  215.336
# Brazil      Paraguay  908.186
# Bolivia         Peru  669.926
# Venezuela   Colombia  639.361
# Argentina    Uruguay   143.07
# Peru         Bolivia  669.926
# Ecuador     Colombia  451.004
# Uruguay    Argentina   143.07
# Paraguay   Argentina  646.036

# %%
#19 and 20 are 2 different ways to do the same thing

# %%
#q20
sa1=sa.copy()
nb=sa1.astype("float").idxmax(skipna=True)
nbd=sa1.max()


sa1["furthest"]=nb
sa1["distance"]=nbd
nb_df=sa1[["furthest","distance"]]
nb_df
# Out:
#             furthest     distance
# Argentina  Venezuela  3157.624051
# Bolivia    Venezuela  1865.131181
# Brazil       Ecuador  2344.584922
# Chile      Venezuela  3043.657689
# Colombia     Uruguay  2962.230943
# Ecuador      Uruguay  2791.196721
# Guyana         Chile  2897.553095
# Paraguay   Venezuela  2544.799572
# Peru         Uruguay  2046.571589
# Suriname       Chile  2895.810776
# Uruguay    Venezuela  3207.352176
# Venezuela    Uruguay  3207.352176

# %%
#Stage2

# %%
import matplotlib

# %%
import numpy as np

# %%
import random

# %%
import sqlite3
conn = sqlite3.connect('big_df')
big_df.to_sql("big_df", conn, if_exists="replace", index=False)
capitals.to_sql("capitals", conn, if_exists="replace", index=False)

# %%
def qry(sql, head=100000):
    return pd.read_sql(sql, conn).head(head)

# %%
#q21
num_cont=qry("""
    SELECT continent, count(country) as 'number of countries' FROM big_df
    GROUP BY continent
    ORDER BY "number of countries" ASC
    """)
num_cont
# Out:
#        continent  number of countries
# 0      Australia                   12
# 1  South America                   12
# 2  North America                   24
# 3           Asia                   38
# 4         Europe                   41
# 5         Africa                   48

# %%
# %matplotlib inline

# %%
#q22
ax_cont = num_cont.plot.bar(x="continent",color="black",fontsize=16)
ax_cont.set_xlabel("continent",fontsize=16)
ax_cont.set_ylabel("number of countries",fontsize=16)
ax_cont.get_legend().remove()

# %%
#q23
con_pop=qry("""
    SELECT continent, sum(population/1000000.000) as 'total population (million)' FROM big_df
    GROUP BY continent
    ORDER BY "total population (million)" DESC
    """)
con_pop
# Out:
#        continent  total population (million)
# 0           Asia                 3739.902863
# 1         Africa                  824.954038
# 2         Europe                  792.053486
# 3  North America                  515.041558
# 4  South America                  375.441666
# 5      Australia                   32.163025

# %%
#q24
ax_pop = con_pop.plot.bar(x="continent",y="total population (million)",color="black",fontsize=16)
ax_pop.set_xlabel("continent",fontsize=16)
ax_pop.set_ylabel("total population (million)",fontsize=16)
ax_pop.yaxis.set_ticks([0,1000,2000,3000])
ax_pop.get_legend().remove()

# %%
#q25
qry("""

SELECT country, population FROM big_df
WHERE continent="Australia"
GROUP BY country
ORDER BY population DESC
""")
# Out:
#              country  population
# 0          Australia    20264082
# 1   Papua New Guinea     5670544
# 2        New Zealand     4076140
# 3               Fiji      905949
# 4   French Polynesia      274578
# 5      New Caledonia      219246
# 6            Vanuatu      208869
# 7              Samoa      176908
# 8               Guam      171019
# 9              Tonga      114689
# 10  Marshall Islands       60422
# 11             Palau       20579

# %%
#q26
real_gdp=qry("""

SELECT country, `gdp-per-capita`*`population`/1000000000.000000 as `real GDP (billion)` FROM big_df

GROUP BY country
ORDER BY `real GDP (billion)` DESC
LIMIT 10
""")
real_gdp
# Out:
#           country  real GDP (billion)
# 0   United States        11281.191327
# 1           China         6569.868565
# 2           Japan         3594.473830
# 3           India         3176.520785
# 4         Germany         2274.855452
# 5          France         1680.181354
# 6  United Kingdom         1678.873538
# 7           Italy         1552.164690
# 8          Brazil         1429.394525
# 9          Russia         1271.752506

# %%
#q27
real_gdp_p = Series(list(real_gdp['real GDP (billion)']),list(real_gdp["country"]))
graph=real_gdp_p.plot.pie(title="GDP Breakdown", figsize=(6,6),label='',fontsize=20)
graph

# %%
#q28
rate=qry("""

SELECT country,"birth-rate", "death-rate" FROM big_df

GROUP BY country
ORDER BY abs(("birth-rate")-("death-rate")) DESC
LIMIT 10
""")
rate
# Out:
#         country  birth-rate  death-rate
# 0        Uganda       47.35       12.24
# 1         Yemen       42.89        8.30
# 2          Mali       49.82       16.89
# 3          Oman       36.24        3.81
# 4    Madagascar       41.41       11.11
# 5  Burkina Faso       45.62       15.60
# 6         Niger       50.73       20.91
# 7          Chad       45.73       16.38
# 8    Mauritania       40.99       12.16
# 9       Burundi       42.22       13.46

# %%
#q29

rate_2=qry("""

SELECT country,"death-rate", "birth-rate" FROM big_df

GROUP BY country
ORDER BY abs(("birth-rate")-("death-rate")) DESC
LIMIT 10
""")

hbar=rate_2.plot.barh(x="country") 
hbar.axis([0,100,-0.5,9.5])
# Out:
# [0, 100, -0.5, 9.5]

# %%
#q30

matplotlib.rcParams["font.size"] = 12

ax = big_df.plot.scatter(x="birth-rate", y="death-rate", c="black", xlim=0, ylim=0)
ax.set_xlabel("birth-rate")
ax.set_ylabel("death-rate")
ax.yaxis.set_ticks([10,20,30])
ax.xaxis.set_ticks([10,20,30,40,50])

# %%
#q31
outlier=qry("""

SELECT country,"birth-rate", "death-rate" FROM big_df
GROUP BY country
HAVING "birth-rate" > 15 and "birth-rate"<32 and "death-rate" > 17 and "death-rate" < 30
ORDER BY "birth-rate" ASC
""")
 
outlier
# Out:
#         country  birth-rate  death-rate
# 0  South Africa       18.20       22.00
# 1      Botswana       23.08       29.50
# 2       Namibia       24.32       18.86
# 3       Lesotho       24.75       28.71
# 4     Swaziland       27.41       29.74
# 5      Zimbabwe       28.01       21.84

# %%
#q32
rate_all=qry("""

SELECT country,"birth-rate", "death-rate" FROM big_df

GROUP BY country
ORDER BY abs(("birth-rate")-("death-rate")) DESC

""")
corr=rate_all["birth-rate"].corr(rate_all["death-rate"])
corr
# Out:
# 0.40037782919521725

# %%
#q33
matplotlib.rcParams["font.size"] = 12

ax_inbr = big_df.plot.scatter(x="infant-mortality", y="birth-rate", c="black", xlim=0, ylim=0)
ax_inbr.set_xlabel("infant-mortality")
ax_inbr.set_ylabel("birth-rate")
ax_inbr.xaxis.set_ticks([0,50,100,150])
ax_inbr.yaxis.set_ticks([10,20,30,40,50])

# %%
#q34
inbr=qry("""

SELECT country,"infant-mortality", "birth-rate" FROM big_df

GROUP BY country

""")
corr=inbr["infant-mortality"].corr(inbr["birth-rate"])
corr
# Out:
# 0.8687265678031413

# %%
#q35
matplotlib.rcParams["font.size"] = 12

ax_deagdp = big_df.plot.scatter(x="gdp-per-capita", y="death-rate", c="black", xlim=0, ylim=0)
ax_deagdp.set_xlabel("gdp-per-capita")
ax_deagdp.set_ylabel("death-rate")
ax_deagdp.xaxis.set_ticks([0,20000,40000])
ax_deagdp.yaxis.set_ticks([10,20,30])

# %%
#q36
deagdp=qry("""

SELECT country,"gdp-per-capita", "death-rate" FROM big_df

GROUP BY country

""")
corr=deagdp["gdp-per-capita"].corr(deagdp["death-rate"])
corr
# Out:
# -0.20995846867456763

# %%
#q37
matplotlib.rcParams["font.size"] =12

ax_brgdp = big_df.plot.scatter(x="gdp-per-capita", y="birth-rate", c="black", xlim=0, ylim=0)
ax_brgdp.set_xlabel("gdp-per-capita")
ax_brgdp.set_ylabel("birth-rate")
ax_brgdp.xaxis.set_ticks([0,20000,40000])
ax_brgdp.yaxis.set_ticks([10,20,30,40,50])

# %%
#q38
new=big_df.copy()


new["inverse"]=1/new["birth-rate"]

matplotlib.rcParams["font.size"] =12

ax_in = new.plot.scatter(x="gdp-per-capita", y="inverse", c="black", xlim=0, ylim=0)
ax_in.set_xlabel("gdp-per-capita")
ax_in.set_ylabel("birth-rate")
ax_in.xaxis.set_ticks([0,20000,40000])
ax_in.yaxis.set_ticks([0.025,0.050,0.075,0.100,0.125])

# %%
#q39
import numpy as np

df = new

df["1"] = 1

res = np.linalg.lstsq(df[["gdp-per-capita", "1"]], df["inverse"], rcond=None)

# res is a tuple: (COEFFICIENTS, VALUE, VALUE, VALUE)
coefficients = res[0] # coefficients is (m,n:
slope = coefficients[0] # slope
intersection = coefficients[1] # intercept
(slope,intersection)
# Out:
# (1.8422394400496347e-06, 0.039035043649535396)

# %%
#q40
import numpy as np

df = new

df["1"] = 1

res = np.linalg.lstsq(df[["gdp-per-capita", "1"]], df["inverse"], rcond=None)

# res is a tuple: (COEFFICIENTS, VALUE, VALUE, VALUE)
coefficients = res[0] # coefficients is (m,n:
slope = coefficients[0] # slope
intsct = coefficients[1] # intercept
ax = df.plot.scatter(x='gdp-per-capita', y='inverse',color="grey")


df["fit"] = df["gdp-per-capita"] * slope + intsct
df.plot.line(x='gdp-per-capita', y='fit', c='red', ax=ax,fontsize=15)
ax.xaxis.set_ticks([0,20000,40000,60000])

# %%
conn.close()

# %%
#Test

# %%
df=DataFrame({"x":[1,2,3,4],
             "y": [4,3,2,1]})

df.plot.line()

# %%
stats={}
results=[]
for i in range(5):
    stats["scores"]=100+i
    results.append(stats)
    print(results)
# Out:
# [{'scores': 100}]
# [{'scores': 101}, {'scores': 101}]
# [{'scores': 102}, {'scores': 102}, {'scores': 102}]
# [{'scores': 103}, {'scores': 103}, {'scores': 103}, {'scores': 103}]
# [{'scores': 104}, {'scores': 104}, {'scores': 104}, {'scores': 104}, {'scores': 104}]

# %%
def mst(n):
    if n==0:
        return 1

    return 2*mst(n-1)
print(mst(3))
# Out:
# 8

# %%
s=Series([5,6,7,8])
s[s%2==0]
# Out:
# 1    6
# 3    8
# dtype: int64

# %%
df=DataFrame({"year":[2015,2016,2017,2018],"cats":[20,15,10,12],"dogs":[30,15,15,18]})
df["next"]=df["year"]+1
df.set_index("year")
#["cats"]
# Out:
#       cats  dogs  next
# year
# 2015    20    30  2016
# 2016    15    15  2017
# 2017    10    15  2018
# 2018    12    18  2019

# %%
9%10
# Out:
# 9

# %%
1%3
# Out:
# 1

# %%
2%2
# Out:
# 0

# %%
y=0
def f(x):
    z=x*2
    #return z
y=f(2)
print(y)
# Out:
# None

# %%
l=[2,3,1,9]
def sr(l):
    l.sort()
    
    return 2
sr(l)
l
# Out:
# [1, 2, 3, 9]

# %%
s=[1,2,3]
s[0]=s[0]+1
s
# Out:
# [2, 2, 3]

# %%
p=(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-281e4cebee0a> in <module>
#       1 p=(1,2)
# ----> 2 p[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %%
def hello():
    print("hello")

def haha():
    return None
    
print(haha==None)
# Out:
# False
